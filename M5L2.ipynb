# %% [markdown]
# <a href="https://colab.research.google.com/github/Anielka5/M5L2/blob/main/M5L2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install bs4

# %%
# !pip3 install bs4
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# ### Zbieranie danych ze strony

# %%
url = 'https://www.thescientificteen.org/technology'

# %%
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
bs = BeautifulSoup(response.text,"lxml")
print(bs)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" id="wixDesktopViewport" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="Wix.com Website Builder" name="generator"/>
# <link href="https://static.wixstatic.com/media/fce14a_fceef848ece64dbb8dcc4608b68727f4%7Emv2.png/v1/fill/w_192%2Ch_192%2Clg_1%2Cusm_0.66_1.00_0.01/fce14a_fceef848ece64dbb8dcc4608b68727f4%7Emv2.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="https://static.wixstatic.com/media/fce14a_fceef848ece64dbb8dcc4608b68727f4%7Emv2.png/v1/fill/w_32%2Ch_32%2Clg_1%2Cusm_0.66_1.00_0.01/fce14a_fceef848ece64dbb8dcc4608b68727f4%7Emv2.png" rel="shortcut icon" type="image/png"/>
# ...

# %%
temp = bs.find_all('a', class_ = "O16KGI pu51Xe lyd6fK xs2MeC")
print(temp)
# Out:
# [<a class="O16KGI pu51Xe lyd6fK xs2MeC" href="https://www.thescientificteen.org/post/decoding-the-quantum-frontier-how-quantum-computing-is-shaping-the-future-of-technology"><div class="FbwBsX blog-post-title-font lyd6fK AkO1lZ xs2MeC HhgCcE" data-hook="post-list-item__title" style="font-size:22px"><div class="T5UMT5 fcPJ4D blog-hover-container-element-color I9XQQf post-title blog-post-post-list-title-color blog-post-post-list-title-font" data-hook="post-title" style="font-size:22px"><h2 class="bD0vt9 KNiaIk" style="-webkit-line-clamp:2">Decoding the Quantum Frontier: How Quantum Computing is Shaping the Future of Technology?</h2></div></div></a>, <a class="O16KGI pu51Xe lyd6fK xs2MeC" href="https://www.thescientificteen.org/post/exploring-coolsculpting-a-deep-dive-into-the-body-contouring-machine"><div class="FbwBsX blog-post-title-font lyd6fK AkO1lZ xs2MeC HhgCcE" data-hook="post-list-item__title" style="font-size:22px"><div class="T5UMT5 fcPJ4D blog-hover-container-element-color I
# ...

# %%
dict_news = {"news": [], "links": []}

for i in temp:
  dict_news["links"].append(i.get('href'))
  dict_news["news"].append(i.find('h2', 'bD0vt9 KNiaIk').text)

# %%
df_news = pd.DataFrame(dict_news, columns=["news", "links"])

# %%
df_news
# Out:
#                                                  news  \
# 0   Decoding the Quantum Frontier: How Quantum Com...
# 1   Exploring CoolSculpting: A Deep Dive into the ...
# 2   An Insightful Discussion on the Positive Effec...
# 3   Seeing the Unseen: How MRI Makes Waves in Medi...
# 4   A Light Touch: How Spectroscopy is Being Used ...
# 5                     Brace Yourself for Flying Taxis
# 6                What On Earth Is A Quantum Computer?
# 7         The Fascinating STEM Behind Hotel Room Keys
# 8                                           Food Mood
# 9   The Rise of Electrical Cars and What that Mean...
# 10  Cryptocurrency: The Trojan Horse of Digitized ...
# 11                                        3D Printers
# 12                  These New Cells Can Age Backwards
# 13            The Future of Injectable Nanotechnology
# 14         Advancements in Obstetrics and Gynecology
#
#                                                 links
# ...

# %% [markdown]
# ## Zbieraj wyświetlenia i komentarze

# %%
import random
dict_news = {"news": [], "links": [], "views": [], "comments": []}
url = 'https://www.thescientificteen.org/technology/'
response = requests.get(url)
bs = BeautifulSoup(response.text,"lxml")
temp = bs.find_all('div', 'iSTCpN lyd6fK post-list-item-wrapper blog-post-post-list-description-font blog-post-post-list-description-color blog-post-post-list-description-fill')

# %% [markdown]
# ## Collecting from all pages

# %%
import random
dict_news = {"news": [], "links": [], "views": [], "comments": []}
temp = bs.find_all('div', 'iSTCpN lyd6fK post-list-item-wrapper blog-post-post-list-description-font blog-post-post-list-description-color blog-post-post-list-description-fill')
pages = ["technology", "medicine", "chemistry", "physics", "earth-and-environment"]

# %%
import random
url = "https://www.thescientificteen.org"
urls = []


for post in temp:
  news_tag = post.find('h2', 'bD0vt9 KNiaIk')
  link_tag = post.find('a', 'O16KGI pu51Xe lyd6fK xs2MeC')
  views = post.find('spam','eYQJQu')
  comment = post.find('spam','eYQJQu')

  dict_news['news'].append(news_tag.text)
  dict_news['links'].append(link_tag.get('href'))
  dict_news['views'].append(random.randint(0, 1000))
  dict_news['comments'].append(random.randint(0, 100))

df_news= pd.DataFrame(dict_news)
df_news
# Out:
#                                                  news  \
# 0   Decoding the Quantum Frontier: How Quantum Com...
# 1   Exploring CoolSculpting: A Deep Dive into the ...
# 2   An Insightful Discussion on the Positive Effec...
# 3   Seeing the Unseen: How MRI Makes Waves in Medi...
# 4   A Light Touch: How Spectroscopy is Being Used ...
# 5                     Brace Yourself for Flying Taxis
# 6                What On Earth Is A Quantum Computer?
# 7         The Fascinating STEM Behind Hotel Room Keys
# 8                                           Food Mood
# 9   The Rise of Electrical Cars and What that Mean...
# 10  Cryptocurrency: The Trojan Horse of Digitized ...
# 11                                        3D Printers
# 12                  These New Cells Can Age Backwards
# 13            The Future of Injectable Nanotechnology
# 14         Advancements in Obstetrics and Gynecology
#
#                                                 links  views  comments
# ...

# %%
url = 'https://www.thescientificteen.org'
#urls = ['https://www.thescientificteen.org/technology', 'https://www.thescientificteen.org/medicine', 'https://www.thescientificteen.org/chemistry', 'https://www.thescientificteen.org/physics', 'https://www.thescientificteen.org/earth-and-environment']
urls = []

for page in pages:
  urls.append(url + "/" + page)
print(urls)

for url in urls:
  response = requests.get(url)
  bs = BeautifulSoup(response.text,"lxml")
  for post in temp:
    news_tag = post.find('h2', 'bD0vt9 KNiaIk')
    link_tag = post.find('a', 'O16KGI pu51Xe lyd6fK xs2MeC')
    views = post.find('span', 'eYQJQu')
    comments = post.find('span', 'eYQJQu')
    #<span title="Apr 3, 2025" class="time-ago" data-hook="time-ago">Apr 3, 2025</span>

    dict_news["news"].append(news_tag.text)
    dict_news["links"].append(link_tag.get("href"))
    dict_news["views"].append(random.randint(0,100))
    dict_news["comments"].append(random.randint(0,100))

    #dict_news["views"].append(views_comments[0].text)
    #dict_news["comments"].append(views_comments[1].text)

df_news = pd.DataFrame(dict_news)
df_news
# Out:
# ['https://www.thescientificteen.org/technology', 'https://www.thescientificteen.org/medicine', 'https://www.thescientificteen.org/chemistry', 'https://www.thescientificteen.org/physics', 'https://www.thescientificteen.org/earth-and-environment']
#                                                  news  \
# 0   Decoding the Quantum Frontier: How Quantum Com...
# 1   Exploring CoolSculpting: A Deep Dive into the ...
# 2   An Insightful Discussion on the Positive Effec...
# 3   Seeing the Unseen: How MRI Makes Waves in Medi...
# 4   A Light Touch: How Spectroscopy is Being Used ...
# ..                                                ...
# 85  Cryptocurrency: The Trojan Horse of Digitized ...
# 86                                        3D Printers
# 87                  These New Cells Can Age Backwards
# 88            The Future of Injectable Nanotechnology
# 89         Advancements in Obstetrics and Gynecology
#
#                                                 links  views  comments
# ...
